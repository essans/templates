# %%
import os
import sys
import pandas as pd

from gsd import ProjectConfigs, gsdIO, gsdUtil, Timer

# %%
# %load_ext autoreload
# %autoreload 2

# %%
project = ProjectConfigs()
project_dir = project.root_dir()
configs = project.configs_from_yaml()

project.print_global_configs()   

outputs_dir = configs['outputs']['outputs_dir']
aws_credentials = configs['credentials']['aws_credentials'])
hf_api = configs['credentials']['hf_api_token']
openai_key = configs['credentials']['openai_key']
perplexity_key = configs['credentials']['perplexity_key']

timer=Timer()
gsdUtil.pd_format()
