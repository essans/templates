# %%
import os
import sys
import pandas as pd

from gsd import ProjectConfigs, gsdIO, gsdUtil, Timer

# %%
# %load_ext autoreload
# %autoreload 2

# %%
project = ProjectConfigs()
project_dir = project.root_dir()
configs = project.configs_from_yaml() #project.print_global_configs()   

data_dir = configs['input_data']['raw_dir']
outputs_dir = configs['outputs']['outputs_dir']
project.set_env_from_creds(verbose=False)

timer=Timer()
gsdUtil.pd_format()
